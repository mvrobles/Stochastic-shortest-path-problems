# %% [markdown]
# # Creación del grafo

# %%
import numpy as np
from timeit import default_timer as timer

# %%
# Número de vértices
N = 10

# Sucesores de cada vértice
grafo = np.zeros((10,10))

# Vecinos de 1
grafo[0,1] = 12; grafo[0,2] = 11; grafo[0,3] = 21

# Vecinos de 2
grafo[1,0] = 12; grafo[1,4] = 21; grafo[1,6] = 16

# Vecinos de 3
grafo[2,0] = 13; grafo[2,1] = 24; grafo[2,5] = 25; grafo[2,7] = 10

# Vecinos de 4
grafo[3,2] = 13; grafo[3,8] = 16

# Vecinos de 5
grafo[4,2] = 7; grafo[4,6] = 9; grafo[4,7] = 11

# Vecinos de 6
grafo[5,3] = 12; grafo[5,7] = 18; grafo[5,8] = 8

# Vecinos de 7
grafo[6,7] = 17; grafo[6,9] = 19

# Vecinos de 8
grafo[7,4] = 4; grafo[7,5] = 21; grafo[7,9] = 13

# Vecinos de 9
grafo[8,7] = 17; grafo[8,9] = 21


# Para saber cuáles son los vecinos de i.
np.nonzero(grafo[6,:])
# Out:
# (array([7, 9], dtype=int64),)

# %% [markdown]
# ### Probabilidades de transición

# %%
# Calcula p(i|j,a) donde a = (i,k)
def prob( i, j, a ):
    if len(a) != 2 or i >= 10 or j >= 10:
        print("Los valores no son correctos: \n i = ", i, 
              '\n j = ', j, '\n a = ', a)
    
    if i == 0: 
        if a == (0,1):
            if j == 1:
                return 0.7
            elif j == 2:
                return 0.1
            elif j == 3:
                return 0.2
        elif a == (0,2):
            if j == 1:
                return 0.2
            elif j == 2:
                return 0.5
            elif j == 3:
                return 0.3
        elif a == (0,3):
            if j == 1:
                return 0.1
            elif j == 2:
                return 0.1
            elif j == 3:
                return 0.8
            
    elif i == 1: 
        if a == (1,0):
            if j == 0:
                return 0.6
            elif j == 4:
                return 0.2
            elif j == 6:
                return 0.2
        elif a == (1,4):
            if j == 0:
                return 0.05
            elif j == 4:
                return 0.9
            elif j == 6:
                return 0.05
        elif a == (1,6):
            if j == 0:
                return 0.1
            elif j == 4:
                return 0.2
            elif j == 6:
                return 0.7
    
    elif i == 2: 
        if a == (2,0):
            if j == 0:
                return 0.6
            elif j == 1:
                return 0.1
            elif j == 5:
                return 0.2
            elif j == 7:
                return 0.1
        elif a == (2,1):
            if j == 0:
                return 0.2
            elif j == 1:
                return 0.4
            elif j == 5:
                return 0.2
            elif j == 7:
                return 0.2
        elif a == (2,5):
            if j == 0:
                return 0.3
            elif j == 1:
                return 0.1
            elif j == 5:
                return 0.4
            elif j == 7:
                return 0.2
        elif a == (2,7):
            if j == 0:
                return 0.3
            elif j == 1:
                return 0.1
            elif j == 5:
                return 0.2
            elif j == 7:
                return 0.4
    
    elif i == 3: 
        if a == (3,2):
            if j == 2:
                return 0.7
            elif j == 8:
                return 0.3
            else:
                return 0
        elif a == (3,8):
            if j == 2:
                return 0.5
            elif j == 8:
                return 0.5
    
    elif i == 4: 
        if a == (4,2):
            if j == 2:
                return 0.6
            elif j == 6:
                return 0.2
            elif j == 7:
                return 0.2
        elif a == (4,6):
            if j == 2:
                return 0.2
            elif j == 6:
                return 0.7
            elif j == 7:
                return 0.1
        elif a == (4,7):
            if j == 2:
                return 0.2
            elif j == 6:
                return 0.3
            elif j == 7:
                return 0.5
    
    elif i == 5: 
        if a == (5,3):
            if j == 3:
                return 0.2
            elif j == 7:
                return 0.5
            elif j == 8:
                return 0.3
        elif a == (5,7):
            if j == 3:
                return 0.2
            elif j == 7:
                return 0.5
            elif j == 8:
                return 0.3
        elif a == (5,8):
            if j == 3:
                return 0.3
            elif j == 7:
                return 0.3
            elif j == 8:
                return 0.4
    
    elif i == 6: 
        if a == (6,7):
            if j == 7:
                return 0.5
            elif j == 9:
                return 0.5
            else:
                return 0
        elif a == (6,9):
            if j == 7:
                return 0.3
            elif j == 9:
                return 0.7
    
    elif i == 7:
        if a == (7,4):
            if j == 4:
                return 0.6
            elif j == 5:
                return 0.2
            elif j == 9:
                return 0.2
        elif a == (7,5):
            if j == 4:
                return 0.2
            elif j == 5:
                return 0.5
            elif j == 9:
                return 0.3
        elif a == (7,9):
            if j == 4:
                return 0.3
            elif j == 5:
                return 0.3
            elif j == 9:
                return 0.4
    
    elif i == 8: 
        if a == (8,7):
            if j == 7:
                return 0.5
            elif j == 9:
                return 0.5
            else:
                return 0
        elif a == (8,9):
            if j == 7:
                return 0.1
            elif j == 9:
                return 0.9
        
    else:
        if j == 9:
            return 1
        else:
            return 0
    
    return 0

# %% [markdown]
# # Value iteration

# %%
def suma(s,a,v0):
    rta = 0
    for j in range(0,M):
        rta += prob(j,s,a)*v0[j]
    return rta

# %%
parar = False
M = 10
iteracion = 0
v0 = np.zeros(M)
eps = 0.01 # PREGUNTAR
    
start = timer()

while parar == False:
    iteracion += 1
    print( '\nIteración número ', iteracion, '\n' )
    vn = np.zeros(M)
    #Itero sobre los estados
    for s in range(0,M):
        valores = np.zeros(np.sum( grafo[s,:]>0 ))
        
        As = np.nonzero( grafo[s,:] > 0 )
        As = np.ndarray.tolist(As[0])
        
        for i in range(0,len(As)):
            print( 'i:',i,'\nAs[i]:', As[i] )
            print( '\nCosto:', grafo[s,As[i]] )
            print( '\nSuma:', suma(s,(s,As[i]),v0) )
            valores[i] = (grafo[s,As[i]] + suma(s,(s,As[i]),v0))
        
        print('valores:',valores)
        vn[s] = np.min(valores)
        
        #Condición de parada
        if np.linalg.norm( np.subtract( vn,v0 ) ) < eps:
            parar = True
        
        v0 = vn
    
    # Fin del ciclo. Calculo la política
    d = np.zeros(M)
    
    for s in range(0,M):
        valores = np.sum( grafo[s,:]>0 )
        
        As = np.nonzero( grafo[s,:] > 0 )
        for a in range(0,np.size(As)):
            valores[a] = grafo[s,As[a]] + suma(s,As[a],v0)
        
        d[s] = As[np.argmin(valores)]


end = timer()
print(end - start)
# Out:
# Iteración número  1
#
# i: 0
# As[i]: 1
#
# Costo: 12.0
#
# Suma: 0.0
# i: 1
# As[i]: 2
#
# Costo: 11.0
#
# Suma: 0.0
# i: 2
# As[i]: 3
#
# Costo: 21.0
#
# Suma: 0.0
# valores: [12. 11. 21.]
# i: 0
# As[i]: 0
#
# Costo: 12.0
#
# Suma: 0.0
# i: 1
# As[i]: 4
#
# Costo: 21.0
#
# Suma: 0.0
# i: 2
# As[i]: 6
#
# Costo: 16.0
#
# Suma: 0.0
# valores: [12. 21. 16.]
# i: 0
# As[i]: 0
#
# Costo: 13.0
#
# Suma: 0.0
# i: 1
# As[i]: 1
#
# Costo: 24.0
#
# Suma: 0.0
# i: 2
# As[i]: 5
#
# Costo: 25.0
#
# Suma: 0.0
# i: 3
# As[i]: 7
#
# Costo: 10.0
#
# Suma: 0.0
# valores: [13. 24. 25. 10.]
# i: 0
# As[i]: 2
#
# Costo: 13.0
#
# Suma: 0.0
# i: 1
# As[i]: 8
#
# Costo: 16.0
#
# Suma: 0.0
# valores: [13. 16.]
# i: 0
# As[i]: 2
#
# Costo: 7.0
#
# Suma: 0.0
# i: 1
# As[i]: 6
#
# Costo: 9.0
#
# Suma: 0.0
# i: 2
# As[i]: 7
#
# Costo: 11.0
#
# Suma: 0.0
# valores: [ 7.  9. 11.]
# i: 0
# As[i]: 3
#
# Costo: 12.0
#
# Suma: 0.0
# i: 1
# As[i]: 7
#
# Costo: 18.0
#
# Suma: 0.0
# i: 2
# As[i]: 8
#
# Costo: 8.0
#
# Suma: 0.0
# valores: [12. 18.  8.]
# i: 0
# As[i]: 7
#
# Costo: 17.0
#
# Suma: 0.0
# i: 1
# As[i]: 9
#
# Costo: 19.0
#
# Suma: 0.0
# valores: [17. 19.]
# i: 0
# As[i]: 4
#
# Costo: 4.0
#
# Suma: 0.0
# i: 1
# As[i]: 5
#
# Costo: 21.0
#
# Suma: 0.0
# i: 2
# As[i]: 9
#
# Costo: 13.0
#
# Suma: 0.0
# valores: [ 4. 21. 13.]
# i: 0
# As[i]: 7
#
# Costo: 17.0
#
# Suma: 0.0
# i: 1
# As[i]: 9
#
# Costo: 21.0
#
# Suma: 0.0
# valores: [17. 21.]
# valores: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-08b6e6fd8ef1> in <module>
#      24             valores[i] = (grafo[s,As[i]] + suma(s,(s,As[i]),v0))
#      25         print('valores:',valores)
# ---> 26         vn[s] = np.min(valores)
#      27
#      28         #Condición de parada
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# ~\anaconda3.2\lib\site-packages\numpy\core\fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2828     6
#    2829     """
# -> 2830     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2831                           keepdims=keepdims, initial=initial, where=where)
#    2832
#
# ~\anaconda3.2\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
As = np.where( grafo[0,:] > 0 )
print(np.ndarray.tolist(As[0]))
# Out:
# [1, 2, 3]
